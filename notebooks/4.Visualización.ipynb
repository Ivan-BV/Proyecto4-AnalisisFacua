# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import sys
sys.path.append("../")
from src import soporte_visualizacion as sv

# %% [markdown]
# # Visualización

# %%
# Recogemos la información de los csv generados
df_aceite_girasol = pd.read_csv("../datos/output/precios_aceite_girasol.csv", index_col=0)
df_aceite_oliva = pd.read_csv("../datos/output/precios_aceite_oliva.csv", index_col=0)
df_leche = pd.read_csv("../datos/output/precios_leche.csv", index_col=0)

# %%
sv.generar_boxplot(df_aceite_girasol, "Precios del aceite de girasol", "Precios (€)", "Supermercados")

# %%
sv.generar_boxplot(df_aceite_oliva, "Precios del aceite de oliva", "Precios (€)", "Supermercados")

# %%
sv.generar_boxplot(df_leche, "Precios de la leche", "Precios (€)", "Supermercados")
